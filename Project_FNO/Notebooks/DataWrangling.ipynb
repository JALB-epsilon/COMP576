# %%
import numpy as np
import matplotlib.pyplot as plt
from timeit import default_timer
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
PATH = '/content/drive/MyDrive/Parallel_PDE_project/fourier_neural_operator'
os.chdir(PATH)

# %%
import sys  
sys.path.insert(0, '/content/drive/MyDrive/Parallel_PDE_project/fourier_neural_operator/Notebooks')

# %%
ntrain = 1000
ntest = 100

sub = 2**3 #subsampling rate
h = 2**13 // sub #total grid size divided by the subsampling rate
s = h

batch_size = 20
learning_rate = 0.001

epochs = 500
step_size = 50
gamma = 0.5

modes = 16
width = 64

# %%
from utils import MatReader

# %%
dataloader = MatReader(os.path.join(PATH, 'data/burgers_data_R10.mat'))

# %%
x_data = dataloader.read_field('a')[:,::sub]
y_data = dataloader.read_field('u')[:,::sub]

x_train = x_data[:ntrain,:]
y_train = y_data[:ntrain,:]
x_test = x_data[-ntest:,:]
y_test = y_data[-ntest:,:]

# %%
save_path = os.path.join(PATH, 'data', 'Burgers')
save_path
# Out:
# '/content/drive/MyDrive/Parallel_PDE_project/fourier_neural_operator/data/Burgers'

# %%
x_train = x_train.reshape(ntrain,s,1)
x_test = x_test.reshape(ntest,s,1)

# %%
torch.save(x_train, os.path.join(save_path,'Burgers_x_train.pt'))
torch.save(x_test, os.path.join(save_path,'Burgers_x_test.pt'))
torch.save(y_train, os.path.join(save_path,'Burgers_y_train.pt'))
torch.save(y_test, os.path.join(save_path,'Burgers_y_test.pt'))
