# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # TASK 3

# %%
plt.plot([1,2,3,4],[1,2,7,14])
plt.axis([0,6,0,20])
plt.show()

# %% [markdown]
# # TASK 4

# %%
X= np.arange(1., 100.)
plt.plot(X ,np.random.rand(X.shape[0]))
plt.show()
